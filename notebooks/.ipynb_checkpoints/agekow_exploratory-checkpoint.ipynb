# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

# %%
class DataLoader():
    def __init__(self):
        self._data_path = "../../data/"

    def loadCsv(self, file_name):
        with open(os.path.join(self._data_path, file_name)) as f:
            csv = pd.read_csv(f)
    
        return csv

# %%
dl = DataLoader()
df_id = dl.loadCsv("train_identity.csv")
df_tr = dl.loadCsv("train_transaction.csv")

df_tr_test = dl.loadCsv("test_transaction.csv")

# %% [markdown]
# ## Transaction Table
# IP, ISP, Proxy, UA, browser, os, etc.associated with the transactions. Field names are masked for privacy
#
# **Cateogorical features**: DeviceType, DeviceInfo, id_12-id_38

# %%
# we see that id_31 is a string with formatting browser + version + OS (sometimes)
# Let's extract the version and browser to use as separate variables
pattern = r'^(.*?)(\d+(?:\.\d+)*)(.*)$'
df_id[['browser', 'version', 'platform']] = df_id['id_31'].str.extract(pattern, expand=True)

# Now let's get all of those that don't include a version number
pattern = r'^([^0-9]*)$'
df_tmp = pd.DataFrame()
df_tmp["browser"] = df_id['id_31'].str.extract(pattern, expand=True)
df_tmp.dropna(inplace=True)

# add these back into the original dataframe
df_id.loc[df_id["browser"].isnull(), "browser"] = df_tmp

# drop the old column
df_id.drop("id_31", inplace=True, axis=1)

# %%
# let's see which rows contain useful data
for col in df_id.columns:
    pass
    print( (len(df_id) - df_id[col].isna().sum()) / len(df_id) *100, f" % of rows contain values for {col}")

# We should throw out anything that is sparesely populated or replace NaN with dummy values
# Out:
# 100.0  % of rows contain values for TransactionID
# 100.0  % of rows contain values for id_01
# 97.66974270797945  % of rows contain values for id_02
# 45.983928781901504  % of rows contain values for id_03
# 45.983928781901504  % of rows contain values for id_04
# 94.8915990099353  % of rows contain values for id_05
# 94.8915990099353  % of rows contain values for id_06
# 3.5740780542594273  % of rows contain values for id_07
# 3.5740780542594273  % of rows contain values for id_08
# 51.94788987263663  % of rows contain values for id_09
# 51.94788987263663  % of rows contain values for id_10
# 97.74323490463348  % of rows contain values for id_11
# 100.0  % of rows contain values for id_12
# 88.27383469802334  % of rows contain values for id_13
# 55.49631499032815  % of rows contain values for id_14
# 97.74808816290307  % of rows contain values for id_15
# 89.67434637010948  % of rows contain values for id_16
# 96.62767882523417  % of rows contain values for id_17
# 31.27786290238711  % of rows contain values for id_18
# 96.59231937212705  % of rows contain values for id_19
# 96.55279998336026  % of rows contain values for id_20
# 3.576851344699202  % of rows contain values for id_21
# 3.5837845707986387  % of rows contain values for id_22
# 3.5837845707986387  % of rows contain values for id_23
# 3.2912024294024254  % of rows contain values for id_24
# 3.558131634230724  % of rows contain values for id_25
# 3.579624635138977  % of rows contain values for id_26
# 3.5837845707986387  % of rows contain values for id_27
# 97.74323490463348  % of rows contain values for id_28
# 97.74323490463348  % of rows contain values for id_29
# 53.77756824027789  % of rows contain values for id_30
# 53.7921280150867  % of rows contain values for id_32
# 50.81292076015891  % of rows contain values for id_33
# 53.943965666664354  % of rows contain values for id_34
# 97.74808816290307  % of rows contain values for id_35
# 97.74808816290307  % of rows contain values for id_36
# 97.74808816290307  % of rows contain values for id_37
# 97.74808816290307  % of rows contain values for id_38
# 97.62675670616294  % of rows contain values for DeviceType
# 82.27382083157114  % of rows contain values for DeviceInfo
# 97.26068236811271  % of rows contain values for browser
# 77.88162209757823  % of rows contain values for version
# 77.88162209757823  % of rows contain values for platform

# %% [markdown]
# TransactionDT: timedelta from a given reference datetime (not an actual timestamp)
# TransactionAMT: transaction payment amount in USD
#
# ProductCD: product code, the product for each transaction
#
# card1 - card6: payment card information, such as card type, card category, issue bank, country, etc.
#
# addr: address
#
# dist: distance
#
# P_ and (R__) emaildomain: purchaser and recipient email domain
#
# C1-C14: counting, such as how many addresses are found to be associated with the payment card, etc. The actual meaning is masked.
#
# D1-D15: timedelta, such as days between previous transaction, etc.
#
# M1-M9: match, such as names on card and address, etc.
#
# Vxxx: Vesta engineered rich features, including ranking, counting, and other entity relations.
#
# Categorical Features:
# ProductCD,
# P_emaildomain,
# R_emaildomain,
# M1 - M9

# %%
def addFeatures(df):
    df["TransactionDay"] = df["TransactionDT"] / (24*60*60)
    d_columns = [f'D{i}' for i in range(1, 16)]
    for i, col in enumerate(d_columns):
        new_var_name = col+"n"
        df[new_var_name] = df["TransactionDay"] - df[col]
    # Add other featurs

    cat_columns = ["ProductCD", "card4", "P_emaildomain", "R_emaildomain"] 
    df = pd.get_dummies(data=df, columns=cat_columns)
    return df

# sample fraction of train data as it is too large
df_tr = df_tr.sample(frac=0.3)
df_tr = addFeatures(df_tr)
df_tr_test = addFeatures(df_tr_test)

# %%
# Filter just the D1-D15 columns
d_columns = [f'D{i}' for i in range(1, 16)]
df = df_tr[d_columns]  # replace `df` with your actual DataFrame

# Set up the grid
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(20, 12))
axes = axes.flatten()  # flatten to easily iterate over

# Plot histograms
for i, col in enumerate(d_columns):
    # Create new variables while we are at it
    new_var_name = col+"n"
    df_tr[new_var_name] = df_tr["TransactionDay"] - df_tr[col]
    df[col].hist(ax=axes[i], bins=30, edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Tight layout
plt.tight_layout()
plt.show()

# %%
def draw_corr_matrix(var_prefix:str, first:int, last:int):
    d_columns = [f'{var_prefix}{i}' for i in range(first, last)]
    df = df_tr[d_columns]
    
    # Compute the correlation matrix
    corr_matrix = df.corr()
    
    # Plot the heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
    plt.title('Correlation Matrix for D1-D15')
    plt.show()

draw_corr_matrix("D",1,16)

# %%
"""
Sinusoidal encoding for time information?
How many of these are linear combinations of each other? Does it matter (yes for linear regression)?
"""
# Out:
# '\nSinusoidal encoding for time information?\nHow many of these are linear combinations of each other? Does it matter (yes for linear regression)?\n'

# %%
# Find correlations with fraud
corr_fraud = df_tr.corrwith(df_tr["isFraud"], numeric_only=True)

# Find least correlated variables
corr_fraud = np.abs(corr_fraud).sort_values(ascending=True)

# %%
# Organize columns which are equally sparsley populated
cols = []
col_dict = {}
for col in df_tr.columns:
    percent_pop = (len(df_tr) - df_tr[col].isna().sum()) / len(df_tr) *100 # percent of rows which are not NaN
    percent_pop = round(percent_pop, 2)
    
    if not percent_pop in col_dict.keys():
        col_dict[percent_pop] = []

    col_dict[percent_pop].append(col)
    print( percent_pop, f" % of rows contain values for {col}")
# Out:
# 100.0  % of rows contain values for TransactionID
# 100.0  % of rows contain values for isFraud
# 100.0  % of rows contain values for TransactionDT
# 100.0  % of rows contain values for TransactionAmt
# 100.0  % of rows contain values for card1
# 98.5  % of rows contain values for card2
# 99.74  % of rows contain values for card3
# 99.27  % of rows contain values for card5
# 99.74  % of rows contain values for card6
# 88.82  % of rows contain values for addr1
# 88.82  % of rows contain values for addr2
# 40.29  % of rows contain values for dist1
# 6.35  % of rows contain values for dist2
# 100.0  % of rows contain values for C1
# 100.0  % of rows contain values for C2
# 100.0  % of rows contain values for C3
# 100.0  % of rows contain values for C4
# 100.0  % of rows contain values for C5
# 100.0  % of rows contain values for C6
# 100.0  % of rows contain values for C7
# 100.0  % of rows contain values for C8
# 100.0  % of rows contain values for C9
# 100.0  % of rows contain values for C10
# 100.0  % of rows contain values for C11
# 100.0  % of rows contain values for C12
# 100.0  % of rows contain values for C13
# 100.0  % of rows contain values for C14
# 99.77  % of rows contain values for D1
# 52.41  % of rows contain values for D2
# 55.42  % of rows contain values for D3
# 71.32  % of rows contain values for D4
# 47.47  % of rows contain values for D5
# 12.44  % of rows contain values for D6
# 6.65  % of rows contain values for D7
# 12.77  % of rows contain values for D8
# 12.77  % of rows contain values for D9
# 86.93  % of rows contain values for D10
# 52.43  % of rows contain values for D11
# 11.01  % of rows contain values for D12
# 10.52  % of rows contain values for D13
# 10.53  % of rows contain values for D14
# 84.67  % of rows contain values for D15
# 53.87  % of rows contain values for M1
# 53.87  % of rows contain values for M2
# 53.87  % of rows contain values for M3
# 52.23  % of rows contain values for M4
# 40.49  % of rows contain values for M5
# 71.11  % of rows contain values for M6
# 41.17  % of rows contain values for M7
# 41.18  % of rows contain values for M8
# 41.18  % of rows contain values for M9
# 52.43  % of rows contain values for V1
# 52.43  % of rows contain values for V2
# 52.43  % of rows contain values for V3
# 52.43  % of rows contain values for V4
# 52.43  % of rows contain values for V5
# 52.43  % of rows contain values for V6
# 52.43  % of rows contain values for V7
# 52.43  % of rows contain values for V8
# 52.43  % of rows contain values for V9
# 52.43  % of rows contain values for V10
# 52.43  % of rows contain values for V11
# 86.93  % of rows contain values for V12
# 86.93  % of rows contain values for V13
# 86.93  % of rows contain values for V14
# 86.93  % of rows contain values for V15
# 86.93  % of rows contain values for V16
# 86.93  % of rows contain values for V17
# 86.93  % of rows contain values for V18
# 86.93  % of rows contain values for V19
# 86.93  % of rows contain values for V20
# 86.93  % of rows contain values for V21
# 86.93  % of rows contain values for V22
# 86.93  % of rows contain values for V23
# 86.93  % of rows contain values for V24
# 86.93  % of rows contain values for V25
# 86.93  % of rows contain values for V26
# 86.93  % of rows contain values for V27
# 86.93  % of rows contain values for V28
# 86.93  % of rows contain values for V29
# 86.93  % of rows contain values for V30
# 86.93  % of rows contain values for V31
# 86.93  % of rows contain values for V32
# 86.93  % of rows contain values for V33
# 86.93  % of rows contain values for V34
# 71.31  % of rows contain values for V35
# 71.31  % of rows contain values for V36
# 71.31  % of rows contain values for V37
# 71.31  % of rows contain values for V38
# 71.31  % of rows contain values for V39
# 71.31  % of rows contain values for V40
# 71.31  % of rows contain values for V41
# 71.31  % of rows contain values for V42
# 71.31  % of rows contain values for V43
# 71.31  % of rows contain values for V44
# 71.31  % of rows contain values for V45
# 71.31  % of rows contain values for V46
# 71.31  % of rows contain values for V47
# 71.31  % of rows contain values for V48
# 71.31  % of rows contain values for V49
# 71.31  % of rows contain values for V50
# 71.31  % of rows contain values for V51
# 71.31  % of rows contain values for V52
# 86.76  % of rows contain values for V53
# 86.76  % of rows contain values for V54
# 86.76  % of rows contain values for V55
# 86.76  % of rows contain values for V56
# 86.76  % of rows contain values for V57
# 86.76  % of rows contain values for V58
# 86.76  % of rows contain values for V59
# 86.76  % of rows contain values for V60
# 86.76  % of rows contain values for V61
# 86.76  % of rows contain values for V62
# 86.76  % of rows contain values for V63
# 86.76  % of rows contain values for V64
# 86.76  % of rows contain values for V65
# 86.76  % of rows contain values for V66
# 86.76  % of rows contain values for V67
# 86.76  % of rows contain values for V68
# 86.76  % of rows contain values for V69
# 86.76  % of rows contain values for V70
# 86.76  % of rows contain values for V71
# 86.76  % of rows contain values for V72
# 86.76  % of rows contain values for V73
# 86.76  % of rows contain values for V74
# 84.66  % of rows contain values for V75
# 84.66  % of rows contain values for V76
# 84.66  % of rows contain values for V77
# 84.66  % of rows contain values for V78
# 84.66  % of rows contain values for V79
# 84.66  % of rows contain values for V80
# 84.66  % of rows contain values for V81
# 84.66  % of rows contain values for V82
# 84.66  % of rows contain values for V83
# 84.66  % of rows contain values for V84
# 84.66  % of rows contain values for V85
# 84.66  % of rows contain values for V86
# 84.66  % of rows contain values for V87
# 84.66  % of rows contain values for V88
# 84.66  % of rows contain values for V89
# 84.66  % of rows contain values for V90
# 84.66  % of rows contain values for V91
# 84.66  % of rows contain values for V92
# 84.66  % of rows contain values for V93
# 84.66  % of rows contain values for V94
# 99.96  % of rows contain values for V95
# 99.96  % of rows contain values for V96
# 99.96  % of rows contain values for V97
# 99.96  % of rows contain values for V98
# 99.96  % of rows contain values for V99
# 99.96  % of rows contain values for V100
# 99.96  % of rows contain values for V101
# 99.96  % of rows contain values for V102
# 99.96  % of rows contain values for V103
# 99.96  % of rows contain values for V104
# 99.96  % of rows contain values for V105
# 99.96  % of rows contain values for V106
# 99.96  % of rows contain values for V107
# 99.96  % of rows contain values for V108
# 99.96  % of rows contain values for V109
# 99.96  % of rows contain values for V110
# 99.96  % of rows contain values for V111
# 99.96  % of rows contain values for V112
# 99.96  % of rows contain values for V113
# 99.96  % of rows contain values for V114
# 99.96  % of rows contain values for V115
# 99.96  % of rows contain values for V116
# 99.96  % of rows contain values for V117
# 99.96  % of rows contain values for V118
# 99.96  % of rows contain values for V119
# 99.96  % of rows contain values for V120
# 99.96  % of rows contain values for V121
# 99.96  % of rows contain values for V122
# 99.96  % of rows contain values for V123
# 99.96  % of rows contain values for V124
# 99.96  % of rows contain values for V125
# 99.96  % of rows contain values for V126
# 99.96  % of rows contain values for V127
# 99.96  % of rows contain values for V128
# 99.96  % of rows contain values for V129
# 99.96  % of rows contain values for V130
# 99.96  % of rows contain values for V131
# 99.96  % of rows contain values for V132
# 99.96  % of rows contain values for V133
# 99.96  % of rows contain values for V134
# 99.96  % of rows contain values for V135
# 99.96  % of rows contain values for V136
# 99.96  % of rows contain values for V137
# 14.04  % of rows contain values for V138
# 14.04  % of rows contain values for V139
# 14.04  % of rows contain values for V140
# 14.04  % of rows contain values for V141
# 14.04  % of rows contain values for V142
# 14.04  % of rows contain values for V143
# 14.04  % of rows contain values for V144
# 14.04  % of rows contain values for V145
# 14.04  % of rows contain values for V146
# 14.04  % of rows contain values for V147
# 14.04  % of rows contain values for V148
# 14.04  % of rows contain values for V149
# 14.04  % of rows contain values for V150
# 14.04  % of rows contain values for V151
# 14.04  % of rows contain values for V152
# 14.04  % of rows contain values for V153
# 14.04  % of rows contain values for V154
# 14.04  % of rows contain values for V155
# 14.04  % of rows contain values for V156
# 14.04  % of rows contain values for V157
# 14.04  % of rows contain values for V158
# 14.04  % of rows contain values for V159
# 14.04  % of rows contain values for V160
# 14.04  % of rows contain values for V161
# 14.04  % of rows contain values for V162
# 14.04  % of rows contain values for V163
# 14.04  % of rows contain values for V164
# 14.04  % of rows contain values for V165
# 14.04  % of rows contain values for V166
# 23.83  % of rows contain values for V167
# 23.83  % of rows contain values for V168
# 23.86  % of rows contain values for V169
# 23.86  % of rows contain values for V170
# 23.86  % of rows contain values for V171
# 23.83  % of rows contain values for V172
# 23.83  % of rows contain values for V173
# 23.86  % of rows contain values for V174
# 23.86  % of rows contain values for V175
# 23.83  % of rows contain values for V176
# 23.83  % of rows contain values for V177
# 23.83  % of rows contain values for V178
# 23.83  % of rows contain values for V179
# 23.86  % of rows contain values for V180
# 23.83  % of rows contain values for V181
# 23.83  % of rows contain values for V182
# 23.83  % of rows contain values for V183
# 23.86  % of rows contain values for V184
# 23.86  % of rows contain values for V185
# 23.83  % of rows contain values for V186
# 23.83  % of rows contain values for V187
# 23.86  % of rows contain values for V188
# 23.86  % of rows contain values for V189
# 23.83  % of rows contain values for V190
# 23.83  % of rows contain values for V191
# 23.83  % of rows contain values for V192
# 23.83  % of rows contain values for V193
# 23.86  % of rows contain values for V194
# 23.86  % of rows contain values for V195
# 23.83  % of rows contain values for V196
# 23.86  % of rows contain values for V197
# 23.86  % of rows contain values for V198
# 23.83  % of rows contain values for V199
# 23.86  % of rows contain values for V200
# 23.86  % of rows contain values for V201
# 23.83  % of rows contain values for V202
# 23.83  % of rows contain values for V203
# 23.83  % of rows contain values for V204
# 23.83  % of rows contain values for V205
# 23.83  % of rows contain values for V206
# 23.83  % of rows contain values for V207
# 23.86  % of rows contain values for V208
# 23.86  % of rows contain values for V209
# 23.86  % of rows contain values for V210
# 23.83  % of rows contain values for V211
# 23.83  % of rows contain values for V212
# 23.83  % of rows contain values for V213
# 23.83  % of rows contain values for V214
# 23.83  % of rows contain values for V215
# 23.83  % of rows contain values for V216
# 22.25  % of rows contain values for V217
# 22.25  % of rows contain values for V218
# 22.25  % of rows contain values for V219
# 24.13  % of rows contain values for V220
# 24.13  % of rows contain values for V221
# 24.13  % of rows contain values for V222
# 22.25  % of rows contain values for V223
# 22.25  % of rows contain values for V224
# 22.25  % of rows contain values for V225
# 22.25  % of rows contain values for V226
# 24.13  % of rows contain values for V227
# 22.25  % of rows contain values for V228
# 22.25  % of rows contain values for V229
# 22.25  % of rows contain values for V230
# 22.25  % of rows contain values for V231
# 22.25  % of rows contain values for V232
# 22.25  % of rows contain values for V233
# 24.13  % of rows contain values for V234
# 22.25  % of rows contain values for V235
# 22.25  % of rows contain values for V236
# 22.25  % of rows contain values for V237
# 24.13  % of rows contain values for V238
# 24.13  % of rows contain values for V239
# 22.25  % of rows contain values for V240
# 22.25  % of rows contain values for V241
# 22.25  % of rows contain values for V242
# 22.25  % of rows contain values for V243
# 22.25  % of rows contain values for V244
# 24.13  % of rows contain values for V245
# 22.25  % of rows contain values for V246
# 22.25  % of rows contain values for V247
# 22.25  % of rows contain values for V248
# 22.25  % of rows contain values for V249
# 24.13  % of rows contain values for V250
# 24.13  % of rows contain values for V251
# 22.25  % of rows contain values for V252
# 22.25  % of rows contain values for V253
# 22.25  % of rows contain values for V254
# 24.13  % of rows contain values for V255
# 24.13  % of rows contain values for V256
# 22.25  % of rows contain values for V257
# 22.25  % of rows contain values for V258
# 24.13  % of rows contain values for V259
# 22.25  % of rows contain values for V260
# 22.25  % of rows contain values for V261
# 22.25  % of rows contain values for V262
# 22.25  % of rows contain values for V263
# 22.25  % of rows contain values for V264
# 22.25  % of rows contain values for V265
# 22.25  % of rows contain values for V266
# 22.25  % of rows contain values for V267
# 22.25  % of rows contain values for V268
# 22.25  % of rows contain values for V269
# 24.13  % of rows contain values for V270
# 24.13  % of rows contain values for V271
# 24.13  % of rows contain values for V272
# 22.25  % of rows contain values for V273
# 22.25  % of rows contain values for V274
# 22.25  % of rows contain values for V275
# 22.25  % of rows contain values for V276
# 22.25  % of rows contain values for V277
# 22.25  % of rows contain values for V278
# 100.0  % of rows contain values for V279
# 100.0  % of rows contain values for V280
# 99.77  % of rows contain values for V281
# 99.77  % of rows contain values for V282
# 99.77  % of rows contain values for V283
# 100.0  % of rows contain values for V284
# 100.0  % of rows contain values for V285
# 100.0  % of rows contain values for V286
# 100.0  % of rows contain values for V287
# 99.77  % of rows contain values for V288
# 99.77  % of rows contain values for V289
# 100.0  % of rows contain values for V290
# 100.0  % of rows contain values for V291
# 100.0  % of rows contain values for V292
# 100.0  % of rows contain values for V293
# 100.0  % of rows contain values for V294
# 100.0  % of rows contain values for V295
# 99.77  % of rows contain values for V296
# 100.0  % of rows contain values for V297
# 100.0  % of rows contain values for V298
# 100.0  % of rows contain values for V299
# 99.77  % of rows contain values for V300
# 99.77  % of rows contain values for V301
# 100.0  % of rows contain values for V302
# 100.0  % of rows contain values for V303
# 100.0  % of rows contain values for V304
# 100.0  % of rows contain values for V305
# 100.0  % of rows contain values for V306
# 100.0  % of rows contain values for V307
# 100.0  % of rows contain values for V308
# 100.0  % of rows contain values for V309
# 100.0  % of rows contain values for V310
# 100.0  % of rows contain values for V311
# 100.0  % of rows contain values for V312
# 99.77  % of rows contain values for V313
# 99.77  % of rows contain values for V314
# 99.77  % of rows contain values for V315
# 100.0  % of rows contain values for V316
# 100.0  % of rows contain values for V317
# 100.0  % of rows contain values for V318
# 100.0  % of rows contain values for V319
# 100.0  % of rows contain values for V320
# 100.0  % of rows contain values for V321
# 14.11  % of rows contain values for V322
# 14.11  % of rows contain values for V323
# 14.11  % of rows contain values for V324
# 14.11  % of rows contain values for V325
# 14.11  % of rows contain values for V326
# 14.11  % of rows contain values for V327
# 14.11  % of rows contain values for V328
# 14.11  % of rows contain values for V329
# 14.11  % of rows contain values for V330
# 14.11  % of rows contain values for V331
# 14.11  % of rows contain values for V332
# 14.11  % of rows contain values for V333
# 14.11  % of rows contain values for V334
# 14.11  % of rows contain values for V335
# 14.11  % of rows contain values for V336
# 14.11  % of rows contain values for V337
# 14.11  % of rows contain values for V338
# 14.11  % of rows contain values for V339
# 100.0  % of rows contain values for TransactionDay
# 99.77  % of rows contain values for D1n
# 52.41  % of rows contain values for D2n
# 55.42  % of rows contain values for D3n
# 71.32  % of rows contain values for D4n
# 47.47  % of rows contain values for D5n
# 12.44  % of rows contain values for D6n
# 6.65  % of rows contain values for D7n
# 12.77  % of rows contain values for D8n
# 12.77  % of rows contain values for D9n
# 86.93  % of rows contain values for D10n
# 52.43  % of rows contain values for D11n
# 11.01  % of rows contain values for D12n
# 10.52  % of rows contain values for D13n
# 10.53  % of rows contain values for D14n
# 84.67  % of rows contain values for D15n
# 100.0  % of rows contain values for ProductCD_C
# 100.0  % of rows contain values for ProductCD_H
# 100.0  % of rows contain values for ProductCD_R
# 100.0  % of rows contain values for ProductCD_S
# 100.0  % of rows contain values for ProductCD_W
# 100.0  % of rows contain values for card4_american express
# 100.0  % of rows contain values for card4_discover
# 100.0  % of rows contain values for card4_mastercard
# 100.0  % of rows contain values for card4_visa
# 100.0  % of rows contain values for P_emaildomain_aim.com
# 100.0  % of rows contain values for P_emaildomain_anonymous.com
# 100.0  % of rows contain values for P_emaildomain_aol.com
# 100.0  % of rows contain values for P_emaildomain_att.net
# 100.0  % of rows contain values for P_emaildomain_bellsouth.net
# 100.0  % of rows contain values for P_emaildomain_cableone.net
# 100.0  % of rows contain values for P_emaildomain_centurylink.net
# 100.0  % of rows contain values for P_emaildomain_cfl.rr.com
# 100.0  % of rows contain values for P_emaildomain_charter.net
# 100.0  % of rows contain values for P_emaildomain_comcast.net
# 100.0  % of rows contain values for P_emaildomain_cox.net
# 100.0  % of rows contain values for P_emaildomain_earthlink.net
# 100.0  % of rows contain values for P_emaildomain_embarqmail.com
# 100.0  % of rows contain values for P_emaildomain_frontier.com
# 100.0  % of rows contain values for P_emaildomain_frontiernet.net
# 100.0  % of rows contain values for P_emaildomain_gmail
# 100.0  % of rows contain values for P_emaildomain_gmail.com
# 100.0  % of rows contain values for P_emaildomain_gmx.de
# 100.0  % of rows contain values for P_emaildomain_hotmail.co.uk
# 100.0  % of rows contain values for P_emaildomain_hotmail.com
# 100.0  % of rows contain values for P_emaildomain_hotmail.de
# 100.0  % of rows contain values for P_emaildomain_hotmail.es
# 100.0  % of rows contain values for P_emaildomain_hotmail.fr
# 100.0  % of rows contain values for P_emaildomain_icloud.com
# 100.0  % of rows contain values for P_emaildomain_juno.com
# 100.0  % of rows contain values for P_emaildomain_live.com
# 100.0  % of rows contain values for P_emaildomain_live.com.mx
# 100.0  % of rows contain values for P_emaildomain_live.fr
# 100.0  % of rows contain values for P_emaildomain_mac.com
# 100.0  % of rows contain values for P_emaildomain_mail.com
# 100.0  % of rows contain values for P_emaildomain_me.com
# 100.0  % of rows contain values for P_emaildomain_msn.com
# 100.0  % of rows contain values for P_emaildomain_netzero.com
# 100.0  % of rows contain values for P_emaildomain_netzero.net
# 100.0  % of rows contain values for P_emaildomain_optonline.net
# 100.0  % of rows contain values for P_emaildomain_outlook.com
# 100.0  % of rows contain values for P_emaildomain_outlook.es
# 100.0  % of rows contain values for P_emaildomain_prodigy.net.mx
# 100.0  % of rows contain values for P_emaildomain_protonmail.com
# 100.0  % of rows contain values for P_emaildomain_ptd.net
# 100.0  % of rows contain values for P_emaildomain_q.com
# 100.0  % of rows contain values for P_emaildomain_roadrunner.com
# 100.0  % of rows contain values for P_emaildomain_rocketmail.com
# 100.0  % of rows contain values for P_emaildomain_sbcglobal.net
# 100.0  % of rows contain values for P_emaildomain_sc.rr.com
# 100.0  % of rows contain values for P_emaildomain_servicios-ta.com
# 100.0  % of rows contain values for P_emaildomain_suddenlink.net
# 100.0  % of rows contain values for P_emaildomain_twc.com
# 100.0  % of rows contain values for P_emaildomain_verizon.net
# 100.0  % of rows contain values for P_emaildomain_web.de
# 100.0  % of rows contain values for P_emaildomain_windstream.net
# 100.0  % of rows contain values for P_emaildomain_yahoo.co.jp
# 100.0  % of rows contain values for P_emaildomain_yahoo.co.uk
# 100.0  % of rows contain values for P_emaildomain_yahoo.com
# 100.0  % of rows contain values for P_emaildomain_yahoo.com.mx
# 100.0  % of rows contain values for P_emaildomain_yahoo.de
# 100.0  % of rows contain values for P_emaildomain_yahoo.es
# 100.0  % of rows contain values for P_emaildomain_yahoo.fr
# 100.0  % of rows contain values for P_emaildomain_ymail.com
# 100.0  % of rows contain values for R_emaildomain_aim.com
# 100.0  % of rows contain values for R_emaildomain_anonymous.com
# 100.0  % of rows contain values for R_emaildomain_aol.com
# 100.0  % of rows contain values for R_emaildomain_att.net
# 100.0  % of rows contain values for R_emaildomain_bellsouth.net
# 100.0  % of rows contain values for R_emaildomain_cableone.net
# 100.0  % of rows contain values for R_emaildomain_centurylink.net
# 100.0  % of rows contain values for R_emaildomain_cfl.rr.com
# 100.0  % of rows contain values for R_emaildomain_charter.net
# 100.0  % of rows contain values for R_emaildomain_comcast.net
# 100.0  % of rows contain values for R_emaildomain_cox.net
# 100.0  % of rows contain values for R_emaildomain_earthlink.net
# 100.0  % of rows contain values for R_emaildomain_embarqmail.com
# 100.0  % of rows contain values for R_emaildomain_frontier.com
# 100.0  % of rows contain values for R_emaildomain_frontiernet.net
# 100.0  % of rows contain values for R_emaildomain_gmail
# 100.0  % of rows contain values for R_emaildomain_gmail.com
# 100.0  % of rows contain values for R_emaildomain_gmx.de
# 100.0  % of rows contain values for R_emaildomain_hotmail.co.uk
# 100.0  % of rows contain values for R_emaildomain_hotmail.com
# 100.0  % of rows contain values for R_emaildomain_hotmail.de
# 100.0  % of rows contain values for R_emaildomain_hotmail.es
# 100.0  % of rows contain values for R_emaildomain_hotmail.fr
# 100.0  % of rows contain values for R_emaildomain_icloud.com
# 100.0  % of rows contain values for R_emaildomain_juno.com
# 100.0  % of rows contain values for R_emaildomain_live.com
# 100.0  % of rows contain values for R_emaildomain_live.com.mx
# 100.0  % of rows contain values for R_emaildomain_live.fr
# 100.0  % of rows contain values for R_emaildomain_mac.com
# 100.0  % of rows contain values for R_emaildomain_mail.com
# 100.0  % of rows contain values for R_emaildomain_me.com
# 100.0  % of rows contain values for R_emaildomain_msn.com
# 100.0  % of rows contain values for R_emaildomain_netzero.com
# 100.0  % of rows contain values for R_emaildomain_netzero.net
# 100.0  % of rows contain values for R_emaildomain_optonline.net
# 100.0  % of rows contain values for R_emaildomain_outlook.com
# 100.0  % of rows contain values for R_emaildomain_outlook.es
# 100.0  % of rows contain values for R_emaildomain_prodigy.net.mx
# 100.0  % of rows contain values for R_emaildomain_protonmail.com
# 100.0  % of rows contain values for R_emaildomain_ptd.net
# 100.0  % of rows contain values for R_emaildomain_q.com
# 100.0  % of rows contain values for R_emaildomain_roadrunner.com
# 100.0  % of rows contain values for R_emaildomain_rocketmail.com
# 100.0  % of rows contain values for R_emaildomain_sbcglobal.net
# 100.0  % of rows contain values for R_emaildomain_sc.rr.com
# 100.0  % of rows contain values for R_emaildomain_scranton.edu
# 100.0  % of rows contain values for R_emaildomain_servicios-ta.com
# 100.0  % of rows contain values for R_emaildomain_suddenlink.net
# 100.0  % of rows contain values for R_emaildomain_twc.com
# 100.0  % of rows contain values for R_emaildomain_verizon.net
# 100.0  % of rows contain values for R_emaildomain_web.de
# 100.0  % of rows contain values for R_emaildomain_windstream.net
# 100.0  % of rows contain values for R_emaildomain_yahoo.co.jp
# 100.0  % of rows contain values for R_emaildomain_yahoo.co.uk
# 100.0  % of rows contain values for R_emaildomain_yahoo.com
# 100.0  % of rows contain values for R_emaildomain_yahoo.com.mx
# 100.0  % of rows contain values for R_emaildomain_yahoo.de
# 100.0  % of rows contain values for R_emaildomain_yahoo.es
# 100.0  % of rows contain values for R_emaildomain_yahoo.fr
# 100.0  % of rows contain values for R_emaildomain_ymail.com

# %%
# Select the D1-D15 columns
draw_corr_matrix("V",240,260)

# %%
# Look at correlation between variables which are sparsely populated
"""
Many variables are sparsley populated. And many appear to be sparsley populated in the same way.
For variables which are sparsley populated in the same way, find out which ones are correlated with each other.
Of the ones which are highly correlated, only keep the one which is most highly correlated with isFraud.
Alternatively: Only keep the one which  has the most unique values
"""
vars_to_keep = []
for percent in col_dict.keys():
    if percent < 50 and len(col_dict[percent]) > 1:
        corr_sparse = df_tr[col_dict[percent]].corr(numeric_only=True)    

        strong_corr = corr_sparse.where((corr_sparse.abs() > 0.75) & (corr_sparse.abs() < 1.0))
        # Do we want to keep sparsley popoulated variables if they aren't correlated with other variables?
        # nan_columns = strong_corr.columns[strong_corr.isna().all()]
        # vars_to_keep += list(nan_columns)
        
        strong_corr_pairs = strong_corr.stack().reset_index()
        strong_corr_pairs.columns = ['Variable 1', 'Variable 2', 'Correlation']
        if len(strong_corr_pairs) == 0: continue
        # remove duplicate pairs
        strong_corr_pairs = strong_corr_pairs[strong_corr_pairs['Variable 1'] < strong_corr_pairs['Variable 2']]
        
        # Find variable most highly correlated with isFraud
        vars_with_strong_corr = pd.unique(
            strong_corr_pairs[['Variable 1', 'Variable 2']].values.ravel()
        )

        ## Keep the variable that is most highy correlated with isFraud
        # corr_fraud = df_tr[vars_with_strong_corr].corrwith(df_tr["isFraud"], numeric_only=True).abs()
        # vars_to_keep.append(corr_fraud.idxmax())

        ## Alternatively, keep the variable with the most unique values
        # vars_to_keep.append(df_tr[vars_with_strong_corr].nunique().idxmax())
        
        ## Or combine the two. Take the variable with the most unique values of the variables which are correlated with isFraud above some threshold
        corr_fraud = df_tr[vars_with_strong_corr].corrwith(df_tr["isFraud"], numeric_only=True).abs() > 0.25 # must be 0.25 correlated
        # select only true values from mask
        corr_fraud = corr_fraud[corr_fraud].index
        # If there are no variables passing the threshold then don't use them
        if len(corr_fraud) < 1:
            continue
            
        vars_to_keep.append(df_tr[corr_fraud].nunique().idxmax())
    else:
        vars_to_keep += col_dict[percent]

# %%
df_tr_keep = df_tr[vars_to_keep]
# do we want to prune these even further?

# %%
# Categorical encoding
"""
which cateogories should be one-hot-encoded vs. ordinal encoded vs. another method such as frequency encoding?

ProductCD has 5 categories. Don't seem to be ordinal. One hot encode
card1-card6:
    card4 and card6 are definitely categorical
    card1, card2 are strings of numbers. Maybe identifiers? Combine with ID information?
    card2 3 digit code
    card3 150 cardinality
    card5 some other 3 digit code

Combine many of these with ID to create unique identifier?
M1-M9 are boolean. Convert this to OHE so we have True,False,NaN

"""

categorical_vars = ["ProductCD", "card1","card2","card3","addr1", "addr2", "P_emaildomain", "R_emaildomain", "M1", "M2"]
# Out:
# '\nwhich cateogories should be one-hot-encoded vs. another method such as frequency encoding?\n'

# %%
#df_tr[["ProductCD", "card1","card2","card3","addr1", "addr2", "P_emaildomain", "R_emaildomain", "M1", "M2"]]

# %%
# Adversarial training to identify feautres which trivally pick out clients
df_tr["isTest"] = 0
df_tr_test["isTest"] = 1

df_mixed = pd.concat([df_tr, df_tr_test], axis=0)
df_mixed = df_mixed.sample(frac=1) #shuffle

df_mixed.drop(["isFraud"], axis=1)
# drop unsed categorical variables at this point. Add them back after figuring out how to deal with them
df_mixed.drop(["card1", "card2", "card3", "card5", "addr1", "addr2"],axis=1)

#only use one set of variables
var_dict_keys = list(col_dict.keys())
df_mixed = df_mixed[col_dict[var_dict_keys[0]] + ["isTest"]]

# create our DMatrix (the XGBoost data structure)
y = df_mixed['isTest']
X = df_mixed.drop(['isTest'], axis=1)
XGBdata = xgb.DMatrix(data=X,label=y)

# our XGBoost parameters
params = {"objective":"binary:logistic",
          "eval_metric":"logloss",
          'learning_rate': 0.05,
          'max_depth': 5, }

# perform cross validation with XGBoost
cross_val_results = xgb.cv(dtrain=XGBdata, params=params, 
                       nfold=5, metrics="auc", 
                       num_boost_round=200,early_stopping_rounds=20,
                       as_pandas=True)

# print out the final result
print((cross_val_results["test-auc-mean"]).tail(1))
